# %%
def countdigit(num):
    count=0
    while(num!=0):
        num//=10
        count=count+1
    print("Digits = ",count,end=" ")
    
def case(j):
    rev=0
    while(j>0):
        rev=(rev*10)+(j%10)
        j//=10
    while(rev!=0):
        r=rev%10
        if(r==9):
            print("Nine",end=" ")
        elif(r==1):
            print("One",end=" ")
        elif(r==2):
            print("Two",end=" ")
        elif(r==3):
            print("Three",end=" ")
        elif(r==4):
            print("Four",end=" ")    
        elif(r==5):
            print("Five",end=" ")
        elif(r==6):
            print("Six",end=" ")
        elif(r==7):
            print("Seven",end=" ")
        elif(r==8):
            print("Eight",end=" ")    
        else:
            print("Zero",end=" ")
        rev//=10   
    
Lower_limit=int(input("Enter lower limit ="))
Upper_limit=int(input("Enter upper limit ="))

for i in range(Lower_limit,Upper_limit+1):
    print(i,":",case(i),",",countdigit(i))
# Out:
# Enter lower limit =455
# Enter upper limit =789
# Four Five Five Digits =  3 455 : None , None
# Four Five Six Digits =  3 456 : None , None
# Four Five Seven Digits =  3 457 : None , None
# Four Five Eight Digits =  3 458 : None , None
# Four Five Nine Digits =  3 459 : None , None
# Four Six Digits =  3 460 : None , None
# Four Six One Digits =  3 461 : None , None
# Four Six Two Digits =  3 462 : None , None
# Four Six Three Digits =  3 463 : None , None
# Four Six Four Digits =  3 464 : None , None
# Four Six Five Digits =  3 465 : None , None
# Four Six Six Digits =  3 466 : None , None
# Four Six Seven Digits =  3 467 : None , None
# Four Six Eight Digits =  3 468 : None , None
# Four Six Nine Digits =  3 469 : None , None
# Four Seven Digits =  3 470 : None , None
# Four Seven One Digits =  3 471 : None , None
# Four Seven Two Digits =  3 472 : None , None
# Four Seven Three Digits =  3 473 : None , None
# Four Seven Four Digits =  3 474 : None , None
# ...
